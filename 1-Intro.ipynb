# %% [markdown]
# 1. The Matplotlib library is super useful for data visualization in Python.
# 2. we will explore the line-graph plotting, bar-chart plotting, and scatter-plot plotting.
# 3. Also we will see the csv file reading using pandas library and create the visualizations based on the data using line-graph, bar-chart, and scatter-plot.
# 4. Histogram plotting is also covered in this tutorial.
# 5. Pie-chart plotting is also covered in this tutorial.
# 6. Box-whisker plot plotting is also covered in this tutorial.
